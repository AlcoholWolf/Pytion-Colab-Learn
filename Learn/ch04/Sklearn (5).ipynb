# %% [markdown]
# <a href="https://colab.research.google.com/github/AlcoholWolf/PY-SAVE/blob/main/ch05_05_%EA%B8%B0%EC%B4%88%EB%AA%A8%EB%8D%B8%EA%B5%AC%ED%98%84_Adaline_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch05.05. 기초모델 구현 - Adaline
# ---
# * 날짜:
# * 이름:
#
# ## 학습내용
#     - 이진 분류 개념에 대해 이해한다.
#     - Adaline 프로세스를 이해한다.
#     - Adaline 알고리즘을 구현한다.
#     - 경사하강법에 대해 이해한다.

# %% [markdown]
# ```
# import numpy as np
# import matplotlib.pyplot as plt
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 클래스 작성
# ---

# %%
class AdalineGD():
    def __init__(self, lr=0.001, random_state=1):
        self.lr=lr
        self.seed = np.random.RandomState(random_state)

    def init_weights(self, X):
        size = X.shape[1] # X의 범위
        self.w = self.seed.normal(0, 0.01, size=size+1) # 변수 랜덤
    

    def model(self, X):
        fx_model = np.dot(X, self.w[:-1]) + self.w[-1]
        return fx_model


    def predict(self, X):
        y_hat = self.model(X)
        logit = np.where(y_hat >= 0.5, 1, 0) # y_hat을 05 기준으로 크면 1 작으면 0 (이진분류) 하기.
        return logit


    def loss(self, y, y_hat):
        fx_loss = np.abs(y-y_hat)**2 # 절대값 지정
        return fx_loss

    
    def accuracy(self, y, y_hat):
        fx_acc = np.count_nonzero( y == y_hat ) / len( y ) # 0이 아닌 모든것을 카운트 // 무조건 y = 을 붙여야 하는가? y_logit 에다가.
        return fx_acc


    def evaluate(self, X, y):
        y_hat = self.predict(X)
        loss = self.loss(y, y_hat) # 로스값 구하기
        lossmin = np.sum(loss)/len(y) # 로스값의 평균
        acc = self.accuracy(y, y_hat)
        return lossmin, acc


    def fit(self, X, y, epochs=10, show_params=False):

        self.init_weights(X) # 가중치 초기화
        self.history=dict(loss=[], acc=[]) # history 초기화

        for epoch in range(epochs):
            for xi, yi in zip(X, y):

                y_logit = self.predict(xi)
                self.w[:-1] += self.lr * (yi - y_logit) * xi # xi 뺀 나머지는 모두 R인데 xi만 V
                self.w[-1] += self.lr * (yi - y_logit) # 여기까지가 최적화
# '''     
# for xi, yi in zip(X, y):
#     for j, xij in xi:
#         y_hat = self.predict(X)
#         self.w[j] += self.lr * (y - y_hat) * X
# self.w
# '''

        
        # 평가 및 결과 저장
        loss, acc = self.evaluate(X, y)
        self.history['loss'].append(loss)
        self.history['acc'].append(acc)
        print(f'[Epoch {epoch}] loss: {np.round(loss,2)}  acc: {np.round(acc,2)}')
        if show_params: print(self.w)

    # 데이터 흐름 시각화
    def draw_dflow(self, X, y, title='', figsize=(8,4)):
        y_hat = self.model(X)
        y_pred = self.predict(X)

        plt.figure(figsize=figsize)
        plt.title(title)
        plt.plot(y, label='y', marker='o')
        plt.plot(y_hat, label='$\hat{y}$', marker='.', linestyle='--')
        plt.plot(y_pred, label='$\logit$', marker='.', linestyle='--')
        plt.legend()
        plt.show()

    # 학습 곡선 시각화
    def draw_lcurve(self, title='', figsize=(8,4)):
        plt.figure(figsize=figsize)
        plt.title(title)
        plt.plot(self.history['acc'], label='acc', marker='o')
        plt.plot(self.history['loss'], label='loss', marker='o')
        plt.xlabel('epoch')
        plt.legend()
        plt.show()

# %% [markdown]
# ## Iris 데이터로 분류 진행
# ---

# %% [markdown]
# ### **데이터 로드**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/py model')

# %%
from data_loader import iris_loader

# %%
X_train, X_test, y_train, y_test = iris_loader(1, 0)
# Out:
# (100, 4) (100,) [5.1 3.5 1.4 0.2] 0
# (75, 4) (25, 4) (75,) (25,)

# %% [markdown]
# ### **학습전 성능 평가**

# %%
model = AdalineGD()

model.init_weights(X_train)
model.draw_dflow(X_train, y_train, figsize=(16,4))
print('성능: ', model.evaluate(X_train, y_train))
# Out:
# 성능:  (0.4666666666666667, 0.5333333333333333)

# %% [markdown]
# ### **학습**

# %%
for _ in range(10):
    history = model.fit(X_train, y_train, epochs=10, show_params=True)
# Out:
# [Epoch 9] loss: 0.0  acc: 1.0
# [ 0.01698461 -0.06255188  0.26238793  0.11319039 -0.0024937 ]
# [Epoch 9] loss: 0.0  acc: 1.0
# [ 0.05462108 -0.10060141  0.26677583  0.10615946  0.01133769]
# [Epoch 9] loss: 0.0  acc: 1.0
# [ 0.02900109 -0.08172428  0.26122142  0.11042214  0.00582815]
# [Epoch 9] loss: 0.0  acc: 1.0
# [ 0.02899381 -0.06855276  0.27901591  0.11502494  0.00900856]
# [Epoch 9] loss: 0.0  acc: 1.0
# [ 0.03316272 -0.0812289   0.26064231  0.10732112  0.00530355]
# [Epoch 9] loss: 0.0  acc: 1.0
# [ 0.03308339 -0.08396754  0.26312827  0.10154794 -0.00671246]
# [Epoch 9] loss: 0.0  acc: 1.0
# [ 0.03987335 -0.0911731   0.27234416  0.12659802  0.00742044]
# [Epoch 9] loss: 0.0  acc: 1.0
# [ 0.03808164 -0.08887629  0.26252842  0.12692455  0.00050808]
# [Epoch 9] loss: 0.0  acc: 1.0
# [ 0.03363004 -0.07809085  0.29100255  0.11120159  0.00617203]
# [Epoch 9] loss: 0.0  acc: 1.0
# [ 0.0430017  -0.0835225   0.25857482  0.10650657 -0.00208894]

# %% [markdown]
# ### **학습 후 성능평가**

# %%
print('성능: ', model.evaluate(X_train, y_train))
model.draw_dflow(X_train, y_train, figsize=(16,4))
# Out:
# 성능:  (0.0, 1.0)

# %% [markdown]
# ### **테스트셋 성능평가**

# %%
print('성능: ', model.evaluate(X_test, y_test))
model.draw_dflow(X_test, y_test, figsize=(16,4))
# Out:
# 성능:  (0.0, 1.0)

# %% [markdown]
# ### **학습곡선**

# %%
model.draw_lcurve()

# %% [markdown]
# ### **하이퍼파라미터에 따른 성능평가**

# %%
for lr in [0.00001, 0.0001, 0.001, 0.01, 0.1]:
  model = AdalineGD(lr=lr)
  history = model.fit(X_train, y_train, epochs=40)
  print(f'===== lr {lr} ==== {model.evaluate(X_test, y_test)}')
# Out:
# [Epoch 39] loss: 0.04  acc: 0.96
# ===== lr 1e-05 ==== (0.04, 0.96)
# [Epoch 39] loss: 0.0  acc: 1.0
# ===== lr 0.0001 ==== (0.0, 1.0)
# [Epoch 39] loss: 0.0  acc: 1.0
# ===== lr 0.001 ==== (0.0, 1.0)
# [Epoch 39] loss: 0.0  acc: 1.0
# ===== lr 0.01 ==== (0.0, 1.0)
# [Epoch 39] loss: 0.0  acc: 1.0
# ===== lr 0.1 ==== (0.0, 1.0)
